# %%
# !pip install torch torchvision --upgrade --force-reinstall
# !pip install --no-deps xformers trl peft accelerate bitsandbytes
# !pip install onnx==1.14
# !pip install triton
# !pip install unsloth-zoo
import torch.onnx
major_version, minor_version = torch.cuda.get_device_capability()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 114.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.2 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.cuda.is_available())  # Should return True if CUDA is set up properly
print(torch.cuda.get_device_name(0))  # Name of your CUDA device
# Out:
# True
# Tesla T4

# %%
# !pip uninstall xformers -y
# !pip install xformers==0.0.27
# Out:
# Found existing installation: xformers 0.0.28.post3
# Uninstalling xformers-0.0.28.post3:
#   Successfully uninstalled xformers-0.0.28.post3
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 102.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 73.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.7 MB/s eta 0:00:00
# ...

# %%
# Downgrade NumPy to a compatible version
# !pip install numpy==1.23.5

# Install a compatible version of TensorFlow
# !pip install tensorflow==2.10.0

# Install the latest version of PyTorch and torchvision
# !pip install torch torchvision --upgrade

# Install unsloth
# !pip install unsloth
# Out:
# ...
#   Using cached numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Using cached numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.0
#     Uninstalling numpy-2.2.0:
#       Successfully uninstalled numpy-2.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albucore 0.0.19 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.20 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# bigframes 1.29.0 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# chex 0.1.88 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# jax 0.4.33 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# ...

# %%
# Importing necessary libraries
import numpy as np
# import tensorflow as tf
import torch

# Importing unsloth
from unsloth import FastLanguageModel

# Check library versions
print(f"NumPy version: {np.__version__}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# NumPy version: 1.23.5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e58f01d9bbdb> in <cell line: 11>()
#       9 # Check library versions
#      10 print(f"NumPy version: {np.__version__}")
# ---> 11 print(f"TensorFlow version: {tf.__version__}")
#      12 print(f"Torch version: {torch.__version__}")
#      13
#
# NameError: name 'tf' is not defined

# %%
# Importing the model
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# Loading the llama3 model as the inference model
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.47.0.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/1.03G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/121 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/459 [00:00<?, ?B/s]

# %%
# The datasets library that will import our training data
# !pip install datasets

# %%
# Importing the Supervised Fintuning Trainer
from trl import SFTTrainer
from transformers import TrainingArguments
from datasets import load_dataset
max_seq_length = 2048


dataset = load_dataset("DEEPAK70681/cryptotwitterv1", split = "train")

# %%
print(dataset[:5])
# Out:
# {'input': ['{"token": "BNB", "category": "DeFi", "market_scenario": "bullish trend", "metrics": {"market cap": "-17.57%", "volume": "-32.14%"}, "twitter_handle": "@NFTMaster", "tone": "direct"}', '{"token": "BNB", "category": "Stablecoin", "market_scenario": "bearish drop", "metrics": {"price": "69.63%", "market cap": "-47.21%"}, "twitter_handle": "@Web3Insider", "tone": "analytical"}', '{"token": "AVAX", "category": "Privacy", "market_scenario": "stable market", "metrics": {"price": "-5.24%", "market cap": "0.78%"}, "twitter_handle": "@AIWhale", "tone": "analytical"}', '{"token": "TOKEN733", "category": "Scaling Solution", "market_cap": "406.8M", "volume": "36.3M", "handle": "@MemeLord"}', '{"token": "BNB51", "category": "Utility Token", "market_cap": "$432B", "price": "$2192.41", "price_change": "+13%", "volume": "$247M", "volume_change": "+11%"}'], 'output': ['$BNB (DeFi): Market cap -17.57%, Volume -32.14%. Market indicates a bullish trend. Stay cautious. @NFTMaster', '$BNB (Stab
# ...

# %%
def generate_text(text):
    inputs = tokenizer(text, return_tensors="pt").to("cuda:0")
    outputs = model.generate(**inputs, max_new_tokens=100)
    print(tokenizer.decode(outputs[0], skip_special_tokens=True))

# %%
# Test Pre-train:
print("Before training\n")
FastLanguageModel.for_inference(model)
generate_text("token=BNB,category=DeFi,market_scenario=bullish trend,metrics={market cap: -17.57%, volume: -32.14%},twitter_handle=@NFTMaster,tone=direct")
# Out:
# Before training
#
# token=BNB,category=DeFi,market_scenario=bullish trend,metrics={market cap: -17.57%, volume: -32.14%},twitter_handle=@NFTMaster,tone=direct,price=0.

# %%
print(dataset[0])  # Check the first sample of the dataset
# Out:
# {'input': '{"token": "BNB", "category": "DeFi", "market_scenario": "bullish trend", "metrics": {"market cap": "-17.57%", "volume": "-32.14%"}, "twitter_handle": "@NFTMaster", "tone": "direct"}', 'output': '$BNB (DeFi): Market cap -17.57%, Volume -32.14%. Market indicates a bullish trend. Stay cautious. @NFTMaster'}

# %%
print(dataset.column_names)  # Lists all column names
# Out:
# ['input', 'output']

# %%
# 4. Do model patching and add fast LoRA weights and training
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    use_gradient_checkpointing = True,
    random_state = 3407,
    max_seq_length = max_seq_length,
    use_rslora = False,  # Rank stabilized LoRA
    loftq_config = None, # LoftQ
)
# 5. using the supervised fine tuning trainer to fine tune the model
trainer = SFTTrainer(
    model = model,
    train_dataset = dataset,
    dataset_text_field = "input",
    max_seq_length = max_seq_length,
    tokenizer = tokenizer,
    args = TrainingArguments(
        per_device_train_batch_size=8,  # Increase batch size if memory permits
        gradient_accumulation_steps=2,  # Adjust based on batch size
        warmup_steps=100,               # Increased warmup steps
        max_steps=100,                  # Increased steps
        fp16=not torch.cuda.is_bf16_supported(),
        bf16=torch.cuda.is_bf16_supported(),
        logging_steps=10,               # Adjusted logging frequency
        output_dir="outputs",
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,

    ),
)
trainer.train()
# Out:
# Unsloth 2024.12.4 patched 16 layers with 16 QKV layers, 16 O layers and 16 MLP layers.
# Map:   0%|          | 0/3700 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 3,700 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 8 | Gradient Accumulation steps = 2
# \        /    Total batch size = 16 | Total steps = 100
#  "-____-"     Number of trainable parameters = 11,272,192
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 01:28, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>6.091400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>5.825800</td>
#     </tr>
#     <tr>
#       <td>30</td>
# ...

# %%
# Test after training
print("\n ######## \nAfter training\n")
FastLanguageModel.for_inference(model)
generate_text("<|begin_of_text|><|start_header_id|>user<|end_header_id|>I have $1000. Can you suggest me 3 tokens where I can invest $1000? Give me the investment distribution<|eot_id|>")
# Out:
#  ########
# After training
#
# userI have $1000. Can you suggest me 3 tokens where I can invest $1000? Give me the investment distributionuser NSCoder I have $1000. Can you suggest me 3 tokens where I can invest $1000? Give me the investment distributionQuestion: I have $1000. Can you suggest me 3 tokens where I can invest $1000? Give me the investment distribution
# I have $1000. Can you suggest me 3 tokens where I can invest $1000? Give me the investment distribution
# I have $1000. Can you suggest me 3 tokens where I

# %%
model.save_pretrained("CryptoXlokiv1")
tokenizer.save_pretrained("DEEPAK70681/CryptoXlokiv1")

# %% [markdown]
# HuggingFace>Settings>AccessTokens>copy the dataset_model(WRITE)

# %%
# !pip install huggingface_hub

# %%
# !huggingface-cli login

# %%
model.push_to_hub("DEEPAK70681/CryptoXlokiv1", token = "paste_your_huggingface_access_token")
 tokenizer.push_to_hub("DEEPAK70681/CryptoXlokiv1", token = "paste_your_huggingface_access_token")

# %% [markdown]
# Save to float16 for VLLM

# %%
# Merge to 16bit
model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# GGUF / llama.cpp Conversion

# %%
# Save to 8bit Q8_0
model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!

    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "", # Get a token at https://huggingface.co/settings/tokens
    )
